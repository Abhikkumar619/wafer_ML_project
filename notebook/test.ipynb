# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path='wafer_23012020_041211.csv'
wafer=pd.read_csv(path)
wafer.head()
# Out:
#   Unnamed: 0  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6  \
# 0  Wafer-801   2968.33   2476.58  2216.7333  1748.0885    1.1127     100.0
# 1  Wafer-802   2961.04   2506.43  2170.0666  1364.5157    1.5447     100.0
# 2  Wafer-803   3072.03   2500.68  2205.7445  1363.1048    1.0518     100.0
# 3  Wafer-804   3021.83   2419.83  2205.7445  1363.1048    1.0518     100.0
# 4  Wafer-805   3006.95   2435.34  2189.8111  1084.6502    1.1993     100.0
#
#    Sensor-7  Sensor-8  Sensor-9  ...  Sensor-582  Sensor-583  Sensor-584  \
# 0   97.5822    0.1242    1.5300  ...         NaN      0.5004      0.0120
# 1   96.7700    0.1230    1.3953  ...         NaN      0.4994      0.0115
# 2  101.8644    0.1220    1.3896  ...         NaN      0.4987      0.0118
# 3  101.8644    0.1220    1.4108  ...         NaN      0.4934      0.0123
# 4  104.8856    0.1234    1.5094  ...         NaN      0.4987      0.0145
#
#    Sensor-585  Sensor-586  Sensor-587  Sensor-588  Sensor-589  Sensor-590  \
# 0      0.0033      2.4069      0.0545      0.0184      0.0055     33.7876
# 1      0.0031      2.3020      0.0545      0.0184      0.0055     33.7876
# 2      0.0036      2.3719      0.0545      0.0184      0.0055     33.7876
# 3      0.0040      2.4923      0.0545      0.0184      0.0055     33.7876
# 4      0.0041      2.8991      0.0545      0.0184      0.0055     33.7876
#
#    Good/Bad
# 0        -1
# 1         1
# 2        -1
# 3        -1
# 4        -1
#
# [5 rows x 592 columns]

# %%
wafer.shape
# Out:
# (100, 592)

# %%
wafer.columns
# Out:
# Index(['Unnamed: 0', 'Sensor-1', 'Sensor-2', 'Sensor-3', 'Sensor-4',
#        'Sensor-5', 'Sensor-6', 'Sensor-7', 'Sensor-8', 'Sensor-9',
#        ...
#        'Sensor-582', 'Sensor-583', 'Sensor-584', 'Sensor-585', 'Sensor-586',
#        'Sensor-587', 'Sensor-588', 'Sensor-589', 'Sensor-590', 'Good/Bad'],
#       dtype='object', length=592)

# %%
wafer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Columns: 592 entries, Unnamed: 0 to Good/Bad
# dtypes: float64(494), int64(97), object(1)
# memory usage: 462.6+ KB

# %%
from sklearn.model_selection import train_test_split
wafers, wafer_test=train_test_split(wafer, test_size=0.20, random_state=42)

# %%
wafers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 80 entries, 55 to 51
# Columns: 592 entries, Unnamed: 0 to Good/Bad
# dtypes: float64(494), int64(97), object(1)
# memory usage: 370.6+ KB

# %%
wafers.describe()
# Out:
#           Sensor-1     Sensor-2     Sensor-3     Sensor-4   Sensor-5  \
# count    79.000000    80.000000    78.000000    78.000000  78.000000
# mean   3019.048228  2494.058875  2202.758988  1519.467071   1.201382
# std      72.665372    68.166898    31.633772   471.962104   0.365870
# min    2889.670000  2254.990000  2114.666700   978.783200   0.753100
# 25%    2975.425000  2452.517500  2189.966700  1111.543600   0.850075
# 50%    3004.390000  2502.445000  2200.955600  1308.647900   1.164250
# 75%    3065.730000  2532.755000  2212.866700  1997.641600   1.383000
# max    3221.210000  2664.520000  2315.266700  2363.641200   2.207300
#
#        Sensor-6    Sensor-7   Sensor-8   Sensor-9  Sensor-10  ...  Sensor-582  \
# count      78.0   78.000000  78.000000  80.000000  80.000000  ...   27.000000
# mean      100.0   96.881160   0.122158   1.460087   0.000946  ...   63.785093
# std         0.0    5.520108   0.002062   0.072159   0.010865  ...   30.722790
# min       100.0   83.423300   0.116000   1.317900  -0.026500  ...   20.309100
# 25%       100.0   93.547250   0.120800   1.409950  -0.005750  ...   46.961400
# 50%       100.0   99.217800   0.122150   1.451900   0.001500  ...   54.476100
# 75%       100.0  101.133300   0.123375   1.498675   0.009000  ...   80.740300
# max       100.0  103.091100   0.126200   1.641100   0.025000  ...  151.193000
#
#        Sensor-583  Sensor-584  Sensor-585  Sensor-586  Sensor-587  Sensor-588  \
# count   80.000000   80.000000   80.000000   80.000000   80.000000   80.000000
# mean     0.499493    0.013905    0.003591    2.785103    0.023543    0.014155
# std      0.003683    0.004577    0.000908    0.923064    0.011668    0.007263
# min      0.492500    0.007600    0.002100    1.515200    0.009900    0.004800
# 25%      0.497175    0.011500    0.003100    2.298350    0.013850    0.009000
# 50%      0.499450    0.012950    0.003400    2.577150    0.021800    0.013100
# 75%      0.501700    0.014950    0.003925    2.992300    0.028100    0.018400
# max      0.508700    0.043700    0.008900    8.816000    0.054500    0.033400
#
#        Sensor-589  Sensor-590   Good/Bad
# count   80.000000   80.000000  80.000000
# mean     0.004439   72.116730  -0.850000
# std      0.002324   50.770394   0.530106
# min      0.001700   20.309100  -1.000000
# 25%      0.002650   33.654025  -1.000000
# 50%      0.003800   59.082500  -1.000000
# 75%      0.005750   93.190025  -1.000000
# max      0.012000  223.101800   1.000000
#
# [8 rows x 591 columns]

# %%
wafers['Good/Bad'].value_counts()
# Out:
# Good/Bad
# -1    74
#  1     6
# Name: count, dtype: int64

# %%
wafers.shape
# Out:
# (80, 592)

# %%
wafers['Good/Bad'].isnull().sum()
# Out:
# 0

# %%
plt.figure(figsize=(15, 100))
for i , col in enumerate(wafers.columns[1:51]):   # Enumerate gives us index including the columns.
    plt.subplot(60, 3, i+1)
    sns.distplot(x=wafers[col], color='indianred')
    plt.xlabel=(col)
    plt.tight_layout()
# Out:
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# c:\TheBritishCollege\DataScience\sensor_project\env\lib\site-packages\seaborn\distributions.py:2511: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# c:\TheBritishCollege\DataScience\sensor_project\env\lib\site-packages\seaborn\distributions.py:2511: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# c:\TheBritishCollege\DataScience\sensor_project\env\lib\site-packages\seaborn\distributions.py:2511: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=wafers[col], color='indianred')
# c:\TheBritishCollege\DataScience\sensor_project\env\lib\site-packages\seaborn\distributions.py:2511: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   kdeplot(**{axis: a}, ax=ax, color=kde_color, **kde_kws)
# C:\Users\abish\AppData\Local\Temp\ipykernel_6224\323372771.py:6: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()

# %%
wafers.isna().sum()/ (wafers.shape[0]* (wafer.shape[1]-1))
# Out:
# Unnamed: 0    0.000000
# Sensor-1      0.000021
# Sensor-2      0.000000
# Sensor-3      0.000042
# Sensor-4      0.000042
#                 ...
# Sensor-587    0.000000
# Sensor-588    0.000000
# Sensor-589    0.000000
# Sensor-590    0.000000
# Good/Bad      0.000000
# Length: 592, dtype: float64

# %%
def get_cols_with_zero_std_dev(df: pd.DataFrame):
    #Return a list of columns names who are having zero standard deviation
    cols_to_drop=[]
    num_cols=[col for col in df.columns if df[col].dtype !='O']
    for col in num_cols:
        if df[col].std() == 0:
            cols_to_drop.append(col)
    return cols_to_drop

# %%
# [col for col in wafer.columns if wafer[col].dtype !='o']

# %%
def get_redundant_cols(df: pd.DataFrame, missing_thresh=.7):
    # Return a list of columns having values more than certain thresh
    cols_missing_ratios=df.isna().sum().div(df.shape[0])
    cols_to_drop=list(cols_missing_ratios[cols_missing_ratios > missing_thresh].index)
    return cols_to_drop

# %%
cols_to_drop_2=get_cols_with_zero_std_dev(df=wafers)

# %%
len(cols_to_drop_2)
# Out:
# 122

# %%
cols_to_drop_1=get_redundant_cols(wafers, missing_thresh=0.7)
cols_to_drop_1
# Out:
# ['Sensor-158', 'Sensor-159', 'Sensor-293', 'Sensor-294']

# %%
cols_to_drop=cols_to_drop_1+cols_to_drop_2

# %%
## Separate Features and Labels Out: 
X, y=wafer.drop(cols_to_drop, axis=1),wafers[['Good/Bad']]

# %%
X=X.drop('Unnamed: 0',axis=1)

# %%
X.shape
# Out:
# (100, 465)

# %%
y.shape
# Out:
# (80, 1)

# %%
X.head()
# Out:
#    Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-7  Sensor-8  \
# 0   2968.33   2476.58  2216.7333  1748.0885    1.1127   97.5822    0.1242
# 1   2961.04   2506.43  2170.0666  1364.5157    1.5447   96.7700    0.1230
# 2   3072.03   2500.68  2205.7445  1363.1048    1.0518  101.8644    0.1220
# 3   3021.83   2419.83  2205.7445  1363.1048    1.0518  101.8644    0.1220
# 4   3006.95   2435.34  2189.8111  1084.6502    1.1993  104.8856    0.1234
#
#    Sensor-9  Sensor-10  Sensor-11  ...  Sensor-582  Sensor-583  Sensor-584  \
# 0    1.5300    -0.0279    -0.0040  ...         NaN      0.5004      0.0120
# 1    1.3953     0.0084     0.0062  ...         NaN      0.4994      0.0115
# 2    1.3896     0.0138     0.0000  ...         NaN      0.4987      0.0118
# 3    1.4108    -0.0046    -0.0024  ...         NaN      0.4934      0.0123
# 4    1.5094    -0.0046     0.0121  ...         NaN      0.4987      0.0145
#
#    Sensor-585  Sensor-586  Sensor-587  Sensor-588  Sensor-589  Sensor-590  \
# 0      0.0033      2.4069      0.0545      0.0184      0.0055     33.7876
# 1      0.0031      2.3020      0.0545      0.0184      0.0055     33.7876
# 2      0.0036      2.3719      0.0545      0.0184      0.0055     33.7876
# 3      0.0040      2.4923      0.0545      0.0184      0.0055     33.7876
# 4      0.0041      2.8991      0.0545      0.0184      0.0055     33.7876
#
#    Good/Bad
# 0        -1
# 1         1
# 2        -1
# 3        -1
# 4        -1
#
# [5 rows x 465 columns]

# %%
y.head()
# Out:
#     Good/Bad
# 55        -1
# 88        -1
# 26        -1
# 42        -1
# 69        -1

# %%
## Data Transformation:
from sklearn.pipeline import Pipeline
from sklearn.impute import KNNImputer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import StandardScaler

# %%
imputer=KNNImputer(n_neighbors=3)
preprocessing_pipeline=Pipeline(
    steps=[('Imputer', imputer),('Scaler',RobustScaler())]
)
preprocessing_pipeline
# Out:
# Pipeline(steps=[('Imputer', KNNImputer(n_neighbors=3)),
#                 ('Scaler', RobustScaler())])

# %% [markdown]
# imputer=KNNIm

# %%
X_trans=preprocessing_pipeline.fit_transform(X)
print("Shape of transformed features set: ", X_trans.shape)
X_trans
# Out:
# Shape of transformed features set:  (100, 465)
# array([[-0.37110152, -0.21388855,  0.67805794, ...,  0.515625  ,
#         -0.40093   ,  0.        ],
#        [-0.44644841,  0.15494872, -1.32959552, ...,  0.515625  ,
#         -0.40093   ,  2.        ],
#        [ 0.70070541,  0.08389967,  0.20530751, ...,  0.515625  ,
#         -0.40093   ,  0.        ],
#        ...,
#        [ 0.83289837, -1.31558137, -1.26792905, ..., -0.671875  ,
#         -0.44021198,  0.        ],
#        [-0.49988372,  0.59310515, -0.16308229, ..., -0.671875  ,
#         -0.44021198,  0.        ],
#        [-0.92374874, -0.35561596,  0.40033513, ..., -0.671875  ,
#         -0.44021198,  2.        ]])
